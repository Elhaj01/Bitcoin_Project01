# %%
import time

debu_chrono=time.time()

p=15486869
def verification(x,y):
    if (x**2)%y==p:
        print("vrai")
    else:
        print("faux")
verification(6543210, 8371779)    
time.sleep(2)
fin_chrono=time.time()
total_chrono=fin_chrono - debu_chrono
print("temps d'execution :",total_chrono)

# %%
import time
debu_chrono=time.time()

p= 101 

def racine(y):
    x=1
    while (x**2)%y !=p:
        x=x+1
    print(x)
racine(17)  

time.sleep(2)
fin_chrono=time.time()
total_chrono= fin_chrono - debu_chrono
print("temps d'execution :",total_chrono)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [27], in <module>
#       9         x=x+1
#      10     print(x)
# ---> 11 racine(17)
#      13 time.sleep(2)
#      14 fin_chrono=time.time()
#
# Input In [27], in racine(y)
#       6 def racine(y):
#       7     x=13
# ----> 8     while (x**2)%y !=p:
#       9         x=x+1
#      10     print(x)
#
# KeyboardInterrupt:
